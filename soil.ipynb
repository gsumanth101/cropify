# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# ImageDataGenerator for testing
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 973 images belonging to 4 classes.
# Found 241 images belonging to 4 classes.
# Found 339 images belonging to 4 classes.

# %%
# Define the model
model = Sequential()

# Convolutional base
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Flattening the output
model.add(Flatten())

# Dense layers for classification
model.add(Dense(512, activation='relu'))  # Adjust the number of units as needed
model.add(Dense(4, activation='softmax'))  # Assuming 4 classes

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Model summary to verify the architecture
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,940,868 (49.37 MB)
#  Trainable params: 12,940,868 (49.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=25
)
# Out:
# Epoch 1/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 421ms/step - accuracy: 0.5312 - loss: 1.2620 - val_accuracy: 0.6518 - val_loss: 0.7953
# Epoch 2/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.2727 - val_accuracy: 0.7059 - val_loss: 0.4069
# Epoch 3/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 389ms/step - accuracy: 0.7519 - loss: 0.6171 - val_accuracy: 0.7902 - val_loss: 0.5792
# Epoch 4/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9062 - loss: 0.1036 - val_accuracy: 0.5882 - val_loss: 0.4940
# Epoch 5/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.8131 - loss: 0.4245 - val_accuracy: 0.7723 - val_loss: 0.4832
# Epoch 6/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8125 - loss: 0.1675 - val_accuracy: 0.9412 - val_loss: 0.1232
# Epoch 7/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.8485 - loss: 0.3822 - val_accuracy: 0.8393 - val_loss: 0.4307
# Epoch 8/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9062 - loss: 0.1002 - val_accuracy: 0.5294 - val_loss: 0.4521
# Epoch 9/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - accuracy: 0.8416 - loss: 0.3676 - val_accuracy: 0.7857 - val_loss: 0.5205
# Epoch 10/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9375 - loss: 0.1440 - val_accuracy: 0.7059 - val_loss: 0.2691
# Epoch 11/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.8634 - loss: 0.3213 - val_accuracy: 0.7812 - val_loss: 0.5819
# Epoch 12/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9375 - loss: 0.1132 - val_accuracy: 0.7059 - val_loss: 0.5715
# Epoch 13/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.9153 - loss: 0.2540 - val_accuracy: 0.8438 - val_loss: 0.4465
# Epoch 14/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9062 - loss: 0.0916 - val_accuracy: 0.8824 - val_loss: 0.2424
# Epoch 15/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.8981 - loss: 0.2523 - val_accuracy: 0.6964 - val_loss: 0.9591
# Epoch 16/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9062 - loss: 0.1935 - val_accuracy: 0.5882 - val_loss: 0.5685
# Epoch 17/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 410ms/step - accuracy: 0.9312 - loss: 0.1868 - val_accuracy: 0.8571 - val_loss: 0.3597
# Epoch 18/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9062 - loss: 0.1022 - val_accuracy: 1.0000 - val_loss: 0.0990
# Epoch 19/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 419ms/step - accuracy: 0.9325 - loss: 0.1740 - val_accuracy: 0.8705 - val_loss: 0.3363
# Epoch 20/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9375 - loss: 0.0821 - val_accuracy: 0.9412 - val_loss: 0.1279
# Epoch 21/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 413ms/step - accuracy: 0.9465 - loss: 0.1430 - val_accuracy: 0.7857 - val_loss: 0.5020
# Epoch 22/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9375 - loss: 0.0910 - val_accuracy: 0.8235 - val_loss: 0.2797
# Epoch 23/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.9402 - loss: 0.1454 - val_accuracy: 0.6964 - val_loss: 0.8278
# Epoch 24/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9375 - loss: 0.0880 - val_accuracy: 0.7647 - val_loss: 0.3948
# Epoch 25/25
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.9263 - loss: 0.1632 - val_accuracy: 0.8170 - val_loss: 0.4346

# %%
loss, accuracy = model.evaluate(test_generator)
print(f'Test loss: {loss:.4f}')
print(f'Test accuracy: {accuracy:.4f}')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.8852 - loss: 0.2978
# Test loss: 0.2976
# Test accuracy: 0.8909

# %%
model.save('soil_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

model = load_model('soil_model.h5')

class_names = ['Alluvial Soil', 'Black Soil', 'Clay Soil', 'Red Soil']

def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(128, 128))
    img = image.img_to_array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=0) 
    return img

def predict_image(image_path):
    img = preprocess_image(image_path)
    prediction = model.predict(img)
    predicted_class = class_names[np.argmax(prediction)]
    return predicted_class

image_path = r'train\Clay soil\Clay_2.jpg' 
result = predict_image(image_path)
print(f'The image is classified as: {result}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# The image is classified as: Clay Soil
